# %% [markdown]
# # Notebook for preparing and saving CP graphs

# %%
import numpy as np
import torch
import pickle
import time
import os
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Download CIFAR dataset

# %%
# if not os.path.isfile('superpixels.zip'):
#     print('downloading..')
#     !curl https://www.dropbox.com/s/y2qwa77a0fxem47/superpixels.zip?dl=1 -o superpixels.zip -J -L -k
#     !unzip superpixels.zip -d ../
#     # !tar -xvf superpixels.zip -C ../
# else:
#     print('File already downloaded')

# %% [markdown]
# # Convert to DGL format and save with pickle

# %%
import os
os.chdir('../../') # go to root folder of the project
print(os.getcwd())
# Out:
# C:\Users\rezav\PycharmProjects\benchmarking-gnns

# %%
pwd
# Out:
# 'C:\\Users\\rezav\\PycharmProjects\\benchmarking-gnns'

# %%
import pickle

# %load_ext autoreload
# %autoreload 2

from data.superpixels import SuperPixDatasetDGL 

from data.data import LoadData
from torch.utils.data import DataLoader
from data.superpixels import SuperPixDataset

# %%
start = time.time()

DATASET_NAME = 'CP'
dataset = SuperPixDatasetDGL(DATASET_NAME) 
print('Time (sec):',time.time() - start) # 636s=10min
# Out:
# Adj matrix defined from super-pixel locations + features
# C:\Users\rezav\.conda\envs\benchmark_gnn\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# coord type before reshape <class 'numpy.ndarray'>
# mean type before reshape <class 'numpy.ndarray'>
# preparing 494 graphs for the TEST set...
# coord type before reshape <class 'numpy.ndarray'>
# mean type before reshape <class 'numpy.ndarray'>
# preparing 2466 graphs for the TRAIN set...
# [I] Data load time: 33.0812s
# Time (sec): 33.08417296409607

# %%
def plot_histo_graphs(dataset, title):
    # histogram of graph sizes
    graph_sizes = []
#     print("we are here1")
    for graph in dataset:
#         print("we are here2")
        print(graph[0])
        graph_sizes.append(graph[0].number_of_nodes())
        #graph_sizes.append(graph[0].number_of_edges())
    plt.figure(1)
    plt.hist(graph_sizes, bins=20)
    plt.title(title)
    plt.show()
    graph_sizes = torch.Tensor(graph_sizes)
    print('nb/min/max :',len(graph_sizes),graph_sizes.min().long().item(),graph_sizes.max().long().item())
    
plot_histo_graphs(dataset.train,'trainset')
plot_histo_graphs(dataset.val,'valset')
plot_histo_graphs(dataset.test,'testset')
# Out:
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=93, num_edges=744,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=90, num_edges=720,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=94, num_edges=752,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=93, num_edges=744,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=94, num_edges=752,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=94, num_edges=752,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=94, num_edges=752,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=94, num_edges=752,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=94, num_edges=752,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=94, num_edges=752,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=94, num_edges=752,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# ...
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=92, num_edges=736,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=98, num_edges=784,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=96, num_edges=768,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=97, num_edges=776,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=95, num_edges=760,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# DGLGraph(num_nodes=99, num_edges=792,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# nb/min/max : 494 90 101

# %%
print(len(dataset.train))
print(len(dataset.val))
print(len(dataset.test))

print(dataset.train[0])
print(dataset.val[0])
print(dataset.test[0])
# Out:
# 2464
# 2
# 494
# (DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)}), tensor(2))
# (DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)}), tensor(0))
# (DGLGraph(num_nodes=100, num_edges=800,
#          ndata_schemes={'feat': Scheme(shape=(5,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)}), tensor(0))

# %%
start = time.time()

with open('data/superpixels/CP.pkl','wb') as f:
        pickle.dump([dataset.train,dataset.val,dataset.test],f)
        
print('Time (sec):',time.time() - start) # 58s
# Out:
# Time (sec): 1.9478821754455566

# %% [markdown]
# # Test load function

# %%
DATASET_NAME = 'CP'
# dataset = LoadData(DATASET_NAME) # 54s
dataset = SuperPixDataset(DATASET_NAME)
trainset, valset, testset = dataset.train, dataset.val, dataset.test
# Out:
# [I] Loading dataset CP...
# train, test, val sizes : 2464 494 2
# [I] Finished loading.
# [I] Data load time: 1.9541s

# %%
start = time.time()

##me: Create mini-batches for MP-GCNs

batch_size = 10
collate = SuperPixDataset.collate
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, collate_fn=collate)
##for the WL-GNN :
#train_loader = DataLoader(dataset.train, shuffle=True, collate_fn=MoleculeDataset.collate_dense_gnn)

print('Time (sec):',time.time() - start) # 0.0001s
# Out:
# Time (sec): 0.0
